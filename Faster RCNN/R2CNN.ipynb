# %% [markdown]
# # 0. Load Modules

# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
import torch

# Core Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Operating System Interaction
import os
import sys

# Machine Learning Frameworks
import torch
from torchvision import datasets
from torch.utils.data import Dataset, DataLoader


# Model Building and Initialization
import torch.nn as nn
from torch.nn.init import kaiming_normal_

# Data Loading and Dataset Handling
from torchvision.datasets import ImageFolder
from torch.utils.data import random_split, Subset
from PIL import Image
import json

# Cross-Validation and Metrics
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score, roc_curve, auc, accuracy_score, confusion_matrix
from scipy.special import expit as sigmoid

# Visualization and Display
from matplotlib.animation import FuncAnimation
from matplotlib.colors import Normalize
import matplotlib.patches as patches

from IPython.display import HTML
from astropy.visualization import ImageNormalize, SqrtStretch
import seaborn as sns
import sunpy.visualization.colormaps as cm

# Miscellaneous
import random
from tqdm import tqdm

# %% [markdown]
# # 1. Import data
# - Image : 166x166
# - Target : labels, boxes, crowd, area, id

# %%
class BoxDataset(Dataset):

    def __init__(self, data_dir, annot_file, mean=None, std=None, transforms=None):
        self.annot_file=annot_file
        self.transforms=transforms
        self.data_dir = data_dir
        self.files = [f for f in os.listdir(data_dir) if self._check_file_shape(f)]
        self.mean = mean
        self.std = std
        self.classes = [_, "jet"] #class 0 is for background


    def _check_file_shape(self, file):
        file_path = os.path.join(self.data_dir, file)
        data = np.load(file_path)['arr_0']
        return data.shape == (166, 166, 30)

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        file_path = os.path.join(self.data_dir, self.files[idx])
        image_name= str(self.files[idx])
        image_name=image_name[:-4] #Getting the number of the event
        data = np.load(file_path)['arr_0']
        data = np.moveaxis(data, -1, 0)  # Move channel to first dimension, shape =(30,166,166)

        data = torch.from_numpy(data[25,:,:]).float()  # Convert to PyTorch tensor


        if self.mean is not None and self.std is not None:
            data = np.clip(data, a_min=None, a_max= 1000)
            data = (data - self.mean) / self.std


        #Annotation file
        df=pd.read_csv(self.annot_file)
        df_im=df[df["id"]==int(image_name)]


        boxes=[]
        labels=[]

        boxes.extend(df_im[["x1","y1","x2","y2"]].values.tolist())
        boxes=torch.as_tensor(boxes,dtype=torch.float32)

        labels=torch.ones(len(boxes)).to(torch.int64) #Box only contain jet so labels are everytime one

        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)

        #group the whole targets
        target={}
        target["boxes"]=boxes
        target["labels"]=labels
        target["image_id"]=torch.tensor([int(image_name)],dtype=torch.int64)
        target["area"]=area
        target["iscrowd"] = iscrowd

        return data, target

# %%
mean_data = 50.564544677734375
std_data = 49.94772720336914


folder1_path = './data/data separated/data1'

folder1_test_path = './data/data separated/data1_test'

folder1_valid_path = './data/data separated/data1_val'

label_dir='./data_boxes/tensor_boxes.pth'

# %%
total_dataset=BoxDataset("./data/data separated/data_jet_image", mean=mean_data, std=std_data, annot_file="./data_boxes/dataframe_pandas.csv")

# %%
def plot_img_bbox(img, target):
    # plot the image and bboxes
    # Bounding boxes are defined as follows: x-min y-min width height
    fig, a = plt.subplots(1,1)
    fig.set_size_inches(5,5)


    vmin, vmax = np.percentile(img, [1, 99.9])
    norm = ImageNormalize(vmin=vmin, vmax=vmax, stretch=SqrtStretch())


    a.imshow(img, cmap='sdoaia304', norm=norm)

    for box in (target['boxes']):
        x, y, width, height  = box[0], box[1], box[2]-box[0], box[3]-box[1]
        rect = patches.Rectangle((x, y),
                                 width, height,
                                 linewidth = 1,
                                 edgecolor = 'w',
                                 facecolor = 'none')

        # Draw the bounding box on top of the image
        a.add_patch(rect)
    plt.show()
    
# plotting the image with bboxes. Feel free to change the index
img, target = total_dataset[860]

print(target)
print(len(total_dataset))
plot_img_bbox(img, target)
# Out:
# {'boxes': tensor([[78.7377, 68.4058, 87.2623, 97.5942]]), 'labels': tensor([1]), 'image_id': tensor([92]), 'area': tensor([248.8210]), 'iscrowd': tensor([0])}
# 866

# %% [markdown]
# # 2. Create Train/Test dataset
# Here we use 80% train, 20% test

# %%
from utils_faster_rcnn import collate_fn
dataset = BoxDataset("./data/data separated/data_jet_image", mean=mean_data, std=std_data, annot_file="./data_boxes/dataframe_pandas.csv")
dataset_test = BoxDataset("./data/data separated/data_jet_image", mean=mean_data, std=std_data, annot_file="./data_boxes/dataframe_pandas.csv")

# split the dataset in train and test set
torch.manual_seed(1)
indices = torch.randperm(len(dataset)).tolist()

# train test split
test_split = 0.2
tsize = int(len(dataset)*test_split)
dataset = torch.utils.data.Subset(dataset, indices[:-tsize])
dataset_test = torch.utils.data.Subset(dataset_test, indices[-tsize:])

img, target=dataset[10]
plot_img_bbox(img, target)
# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=10, shuffle=True, collate_fn=collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=10, shuffle=False, collate_fn=collate_fn)

# %% [markdown]
# # 3. Create Model

# %%
class R2CNN(nn.Module):
    def __init__(self):
        super().__init__()

        self.max_pool = nn.MaxPool2d(kernel_size=2,stride=2)
        self.layer1 = nn.Sequential(
            nn.Conv2d(30,64,kernel_size=3,padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(64,64,kernel_size=3,padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )
        self.layer3 = nn.Sequential(
            nn.Conv2d(64,128,kernel_size=3,padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True)
        )
        self.layer4 = nn.Sequential(
            nn.Conv2d(128,128,kernel_size=3,padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True)
        )
        self.layer5 = nn.Sequential(
            nn.Conv2d(128,256,kernel_size=3,padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True)
        )
        self.layer6 = nn.Sequential(
            nn.Conv2d(256,256,kernel_size=3,padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True)
        )
        self.layer7 = nn.Sequential(
            nn.Conv2d(256,512,kernel_size=3,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True)
        )
        self.layer8 = nn.Sequential(
            nn.Conv2d(512,512,kernel_size=3,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True)
        )
       
        self.lstm = nn.LSTM(input_size=12800, hidden_size=256, num_layers=1, batch_first=True)

        self.classifier = nn.Sequential(
            nn.Linear(256,128),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(128,32),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(32,1),
            #nn.Sigmoid()     # don't include it as it is already included in BCELogitLoss (BCELoss is less stable)
        )

        for m in self.modules():
            if isinstance(m, (nn.Conv2d, nn.Linear)):
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

    def forward(self,x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.max_pool(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.max_pool(out)
        out = self.layer5(out)
        out = self.layer6(out)
        out = self.max_pool(out)
        out = self.layer7(out)
        out = self.layer8(out)
        out = self.max_pool(out)
        out = self.layer8(out)
        out = self.layer8(out)
        out = self.max_pool(out)
        out = out.view(out.size(0),-1)
        lstm_out, _ = self.lstm(out)
        out = self.classifier(lstm_out)

        return out

    def graph(self): #for visualization and debugging
        return nn.Sequential(self.layer1,self.layer2,self.maxPool,self.layer3,self.layer4,self.maxPool,self.layer5,self.layer6,self.maxPool,self.layer7,self.layer8, self.maxPool,self.layer8,self.layer8,self.maxPool,self.classifier)

# %%
num_classes=2 #one for jet, one for background
in_features=model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor=FastRCNNPredictor(in_features, num_classes)

# %% [markdown]
# # 4. Train the model

# %%
device=torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device
# Out:
# device(type='cuda')

# %%
model.to(device)

params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.001, momentum=0.9, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)

# %%
from train_eval_faster_rcnn import *

# %%
num_epochs=10

for epoch in range(num_epochs):
    # training for one epoch
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [ 0/70]  eta: 0:05:41  lr: 0.000015  loss: 1.2147 (1.2147)  loss_classifier: 0.2491 (0.2491)  loss_box_reg: 0.0266 (0.0266)  loss_objectness: 0.9142 (0.9142)  loss_rpn_box_reg: 0.0248 (0.0248)  time: 4.8819  data: 0.1121  max mem: 7145
# Epoch: [0]  [10/70]  eta: 0:02:18  lr: 0.000160  loss: 0.6811 (0.7423)  loss_classifier: 0.3295 (0.3330)  loss_box_reg: 0.0286 (0.0318)  loss_objectness: 0.3170 (0.3495)  loss_rpn_box_reg: 0.0248 (0.0281)  time: 2.3050  data: 0.1038  max mem: 7303
# Epoch: [0]  [20/70]  eta: 0:02:03  lr: 0.000305  loss: 0.5525 (0.5957)  loss_classifier: 0.1784 (0.2361)  loss_box_reg: 0.0545 (0.0527)  loss_objectness: 0.1917 (0.2791)  loss_rpn_box_reg: 0.0230 (0.0278)  time: 2.3463  data: 0.1033  max mem: 7303
# Epoch: [0]  [30/70]  eta: 0:01:35  lr: 0.000450  loss: 0.3868 (0.5957)  loss_classifier: 0.1059 (0.1885)  loss_box_reg: 0.0584 (0.0506)  loss_objectness: 0.1634 (0.3232)  loss_rpn_box_reg: 0.0277 (0.0333)  time: 2.4209  data: 0.1038  max mem: 7303
# Epoch: [0]  [40/70]  eta: 0:01:10  lr: 0.000595  loss: 0.2019 (0.4931)  loss_classifier: 0.0622 (0.1568)  loss_box_reg: 0.0362 (0.0469)  loss_objectness: 0.1048 (0.2609)  loss_rpn_box_reg: 0.0159 (0.0285)  time: 2.2451  data: 0.1259  max mem: 7303
# Epoch: [0]  [50/70]  eta: 0:00:48  lr: 0.000739  loss: 0.1659 (0.4296)  loss_classifier: 0.0622 (0.1394)  loss_box_reg: 0.0362 (0.0458)  loss_objectness: 0.0492 (0.2185)  loss_rpn_box_reg: 0.0117 (0.0259)  time: 2.5164  data: 0.1594  max mem: 7303
# Epoch: [0]  [60/70]  eta: 0:00:24  lr: 0.000884  loss: 0.1709 (0.3900)  loss_classifier: 0.0704 (0.1281)  loss_box_reg: 0.0410 (0.0456)  loss_objectness: 0.0461 (0.1921)  loss_rpn_box_reg: 0.0114 (0.0241)  time: 2.7220  data: 0.1652  max mem: 7303
# Epoch: [0]  [69/70]  eta: 0:00:02  lr: 0.001000  loss: 0.1674 (0.3599)  loss_classifier: 0.0646 (0.1199)  loss_box_reg: 0.0442 (0.0458)  loss_objectness: 0.0381 (0.1717)  loss_rpn_box_reg: 0.0109 (0.0225)  time: 2.5929  data: 0.1561  max mem: 7303
# Epoch: [0] Total time: 0:02:53 (2.4754 s / it)
# creating index...
# index created!
# Test:  [ 0/18]  eta: 0:00:18  model_time: 0.8112 (0.8112)  evaluator_time: 0.0048 (0.0048)  time: 1.0053  data: 0.1892  max mem: 7303
# Test:  [17/18]  eta: 0:00:00  model_time: 0.5519 (0.5481)  evaluator_time: 0.0048 (0.0055)  time: 0.7159  data: 0.1609  max mem: 7303
# Test: Total time: 0:00:12 (0.7159 s / it)
# Averaged stats: model_time: 0.5519 (0.5481)  evaluator_time: 0.0048 (0.0055)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.023
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.073
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [1]  [ 0/70]  eta: 0:03:14  lr: 0.001000  loss: 0.1469 (0.1469)  loss_classifier: 0.0545 (0.0545)  loss_box_reg: 0.0461 (0.0461)  loss_objectness: 0.0269 (0.0269)  loss_rpn_box_reg: 0.0194 (0.0194)  time: 2.7751  data: 0.1973  max mem: 7303
# Epoch: [1]  [10/70]  eta: 0:02:39  lr: 0.001000  loss: 0.1665 (0.1618)  loss_classifier: 0.0608 (0.0651)  loss_box_reg: 0.0497 (0.0517)  loss_objectness: 0.0318 (0.0324)  loss_rpn_box_reg: 0.0093 (0.0126)  time: 2.6635  data: 0.1582  max mem: 7303
# Epoch: [1]  [20/70]  eta: 0:02:15  lr: 0.001000  loss: 0.1527 (0.1594)  loss_classifier: 0.0628 (0.0656)  loss_box_reg: 0.0502 (0.0506)  loss_objectness: 0.0305 (0.0316)  loss_rpn_box_reg: 0.0095 (0.0116)  time: 2.6964  data: 0.1625  max mem: 7303
# Epoch: [1]  [30/70]  eta: 0:01:46  lr: 0.001000  loss: 0.1632 (0.1662)  loss_classifier: 0.0641 (0.0657)  loss_box_reg: 0.0504 (0.0512)  loss_objectness: 0.0327 (0.0370)  loss_rpn_box_reg: 0.0103 (0.0123)  time: 2.6449  data: 0.1501  max mem: 7303
# Epoch: [1]  [40/70]  eta: 0:01:18  lr: 0.001000  loss: 0.1656 (0.1656)  loss_classifier: 0.0637 (0.0656)  loss_box_reg: 0.0510 (0.0519)  loss_objectness: 0.0327 (0.0360)  loss_rpn_box_reg: 0.0102 (0.0122)  time: 2.5472  data: 0.1198  max mem: 7303
# Epoch: [1]  [50/70]  eta: 0:00:52  lr: 0.001000  loss: 0.1573 (0.1642)  loss_classifier: 0.0613 (0.0651)  loss_box_reg: 0.0554 (0.0526)  loss_objectness: 0.0299 (0.0346)  loss_rpn_box_reg: 0.0101 (0.0119)  time: 2.6080  data: 0.1216  max mem: 7303
# Epoch: [1]  [60/70]  eta: 0:00:26  lr: 0.001000  loss: 0.1535 (0.1619)  loss_classifier: 0.0606 (0.0641)  loss_box_reg: 0.0524 (0.0517)  loss_objectness: 0.0233 (0.0341)  loss_rpn_box_reg: 0.0108 (0.0120)  time: 2.6678  data: 0.1277  max mem: 7303
# Epoch: [1]  [69/70]  eta: 0:00:02  lr: 0.001000  loss: 0.1481 (0.1609)  loss_classifier: 0.0606 (0.0635)  loss_box_reg: 0.0481 (0.0509)  loss_objectness: 0.0263 (0.0338)  loss_rpn_box_reg: 0.0108 (0.0126)  time: 2.5524  data: 0.1192  max mem: 7303
# Epoch: [1] Total time: 0:03:02 (2.6096 s / it)
# creating index...
# index created!
# Test:  [ 0/18]  eta: 0:00:17  model_time: 0.7812 (0.7812)  evaluator_time: 0.0000 (0.0000)  time: 0.9531  data: 0.1719  max mem: 7303
# Test:  [17/18]  eta: 0:00:00  model_time: 0.5599 (0.5488)  evaluator_time: 0.0000 (0.0039)  time: 0.7070  data: 0.1531  max mem: 7303
# Test: Total time: 0:00:12 (0.7070 s / it)
# Averaged stats: model_time: 0.5599 (0.5488)  evaluator_time: 0.0000 (0.0039)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.112
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [2]  [ 0/70]  eta: 0:03:12  lr: 0.001000  loss: 0.1367 (0.1367)  loss_classifier: 0.0593 (0.0593)  loss_box_reg: 0.0475 (0.0475)  loss_objectness: 0.0220 (0.0220)  loss_rpn_box_reg: 0.0079 (0.0079)  time: 2.7435  data: 0.1931  max mem: 7303
# Epoch: [2]  [10/70]  eta: 0:02:26  lr: 0.001000  loss: 0.1455 (0.1487)  loss_classifier: 0.0567 (0.0569)  loss_box_reg: 0.0454 (0.0458)  loss_objectness: 0.0334 (0.0322)  loss_rpn_box_reg: 0.0119 (0.0138)  time: 2.4403  data: 0.1408  max mem: 7303
# Epoch: [2]  [20/70]  eta: 0:01:59  lr: 0.001000  loss: 0.1415 (0.1429)  loss_classifier: 0.0566 (0.0568)  loss_box_reg: 0.0446 (0.0446)  loss_objectness: 0.0272 (0.0285)  loss_rpn_box_reg: 0.0119 (0.0130)  time: 2.3753  data: 0.1205  max mem: 7303
# Epoch: [2]  [30/70]  eta: 0:01:35  lr: 0.001000  loss: 0.1388 (0.1433)  loss_classifier: 0.0556 (0.0567)  loss_box_reg: 0.0446 (0.0462)  loss_objectness: 0.0237 (0.0274)  loss_rpn_box_reg: 0.0112 (0.0131)  time: 2.3403  data: 0.1062  max mem: 7303
# Epoch: [2]  [40/70]  eta: 0:01:11  lr: 0.001000  loss: 0.1482 (0.1473)  loss_classifier: 0.0560 (0.0580)  loss_box_reg: 0.0527 (0.0488)  loss_objectness: 0.0238 (0.0275)  loss_rpn_box_reg: 0.0112 (0.0130)  time: 2.3393  data: 0.1075  max mem: 7303
# Epoch: [2]  [50/70]  eta: 0:00:47  lr: 0.001000  loss: 0.1518 (0.1485)  loss_classifier: 0.0629 (0.0593)  loss_box_reg: 0.0552 (0.0500)  loss_objectness: 0.0238 (0.0271)  loss_rpn_box_reg: 0.0093 (0.0122)  time: 2.3429  data: 0.1081  max mem: 7303
# Epoch: [2]  [60/70]  eta: 0:00:23  lr: 0.001000  loss: 0.1529 (0.1495)  loss_classifier: 0.0633 (0.0602)  loss_box_reg: 0.0567 (0.0511)  loss_objectness: 0.0235 (0.0264)  loss_rpn_box_reg: 0.0084 (0.0118)  time: 2.3458  data: 0.1085  max mem: 7303
# Epoch: [2]  [69/70]  eta: 0:00:02  lr: 0.001000  loss: 0.1589 (0.1521)  loss_classifier: 0.0646 (0.0611)  loss_box_reg: 0.0569 (0.0525)  loss_objectness: 0.0212 (0.0265)  loss_rpn_box_reg: 0.0096 (0.0120)  time: 2.2316  data: 0.1046  max mem: 7303
# Epoch: [2] Total time: 0:02:43 (2.3297 s / it)
# creating index...
# index created!
# Test:  [ 0/18]  eta: 0:00:20  model_time: 0.9348 (0.9348)  evaluator_time: 0.0090 (0.0090)  time: 1.1153  data: 0.1715  max mem: 7303
# Test:  [17/18]  eta: 0:00:00  model_time: 0.5504 (0.5544)  evaluator_time: 0.0100 (0.0125)  time: 0.7225  data: 0.1550  max mem: 7303
# Test: Total time: 0:00:13 (0.7225 s / it)
# Averaged stats: model_time: 0.5504 (0.5544)  evaluator_time: 0.0100 (0.0125)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.022
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.097
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.179
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.115
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.245
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.267
# Epoch: [3]  [ 0/70]  eta: 0:03:16  lr: 0.000100  loss: 0.1561 (0.1561)  loss_classifier: 0.0597 (0.0597)  loss_box_reg: 0.0613 (0.0613)  loss_objectness: 0.0251 (0.0251)  loss_rpn_box_reg: 0.0100 (0.0100)  time: 2.8003  data: 0.2100  max mem: 7303
# Epoch: [3]  [10/70]  eta: 0:02:35  lr: 0.000100  loss: 0.1561 (0.1557)  loss_classifier: 0.0618 (0.0629)  loss_box_reg: 0.0584 (0.0567)  loss_objectness: 0.0219 (0.0230)  loss_rpn_box_reg: 0.0100 (0.0132)  time: 2.5932  data: 0.1591  max mem: 7303
# Epoch: [3]  [20/70]  eta: 0:02:09  lr: 0.000100  loss: 0.1527 (0.1521)  loss_classifier: 0.0618 (0.0618)  loss_box_reg: 0.0535 (0.0543)  loss_objectness: 0.0215 (0.0237)  loss_rpn_box_reg: 0.0112 (0.0123)  time: 2.5735  data: 0.1554  max mem: 7303
# Epoch: [3]  [30/70]  eta: 0:01:43  lr: 0.000100  loss: 0.1517 (0.1522)  loss_classifier: 0.0620 (0.0626)  loss_box_reg: 0.0526 (0.0544)  loss_objectness: 0.0211 (0.0233)  loss_rpn_box_reg: 0.0096 (0.0119)  time: 2.5860  data: 0.1603  max mem: 7303
# Epoch: [3]  [40/70]  eta: 0:01:17  lr: 0.000100  loss: 0.1460 (0.1511)  loss_classifier: 0.0620 (0.0623)  loss_box_reg: 0.0526 (0.0546)  loss_objectness: 0.0211 (0.0228)  loss_rpn_box_reg: 0.0085 (0.0113)  time: 2.5917  data: 0.1642  max mem: 7303
# Epoch: [3]  [50/70]  eta: 0:00:51  lr: 0.000100  loss: 0.1398 (0.1498)  loss_classifier: 0.0564 (0.0616)  loss_box_reg: 0.0528 (0.0549)  loss_objectness: 0.0215 (0.0221)  loss_rpn_box_reg: 0.0090 (0.0112)  time: 2.5823  data: 0.1581  max mem: 7303
# Epoch: [3]  [60/70]  eta: 0:00:25  lr: 0.000100  loss: 0.1397 (0.1497)  loss_classifier: 0.0554 (0.0611)  loss_box_reg: 0.0545 (0.0548)  loss_objectness: 0.0230 (0.0225)  loss_rpn_box_reg: 0.0099 (0.0113)  time: 2.5858  data: 0.1523  max mem: 7303
# Epoch: [3]  [69/70]  eta: 0:00:02  lr: 0.000100  loss: 0.1544 (0.1511)  loss_classifier: 0.0625 (0.0612)  loss_box_reg: 0.0570 (0.0550)  loss_objectness: 0.0234 (0.0230)  loss_rpn_box_reg: 0.0108 (0.0118)  time: 2.4897  data: 0.1516  max mem: 7303
# Epoch: [3] Total time: 0:02:59 (2.5653 s / it)
# creating index...
# index created!
# Test:  [ 0/18]  eta: 0:00:20  model_time: 0.9665 (0.9665)  evaluator_time: 0.0068 (0.0068)  time: 1.1520  data: 0.1787  max mem: 7303
# Test:  [17/18]  eta: 0:00:00  model_time: 0.5570 (0.5575)  evaluator_time: 0.0100 (0.0085)  time: 0.7200  data: 0.1528  max mem: 7303
# Test: Total time: 0:00:12 (0.7200 s / it)
# Averaged stats: model_time: 0.5570 (0.5575)  evaluator_time: 0.0100 (0.0085)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.097
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.145
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.103
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.100
# Epoch: [4]  [ 0/70]  eta: 0:03:13  lr: 0.000100  loss: 0.1642 (0.1642)  loss_classifier: 0.0624 (0.0624)  loss_box_reg: 0.0558 (0.0558)  loss_objectness: 0.0312 (0.0312)  loss_rpn_box_reg: 0.0148 (0.0148)  time: 2.7617  data: 0.1826  max mem: 7303
# Epoch: [4]  [10/70]  eta: 0:02:37  lr: 0.000100  loss: 0.1540 (0.1528)  loss_classifier: 0.0624 (0.0619)  loss_box_reg: 0.0558 (0.0550)  loss_objectness: 0.0220 (0.0221)  loss_rpn_box_reg: 0.0119 (0.0139)  time: 2.6266  data: 0.1678  max mem: 7303
# Epoch: [4]  [20/70]  eta: 0:02:11  lr: 0.000100  loss: 0.1553 (0.1539)  loss_classifier: 0.0630 (0.0626)  loss_box_reg: 0.0542 (0.0562)  loss_objectness: 0.0220 (0.0231)  loss_rpn_box_reg: 0.0092 (0.0120)  time: 2.6152  data: 0.1693  max mem: 7303
# Epoch: [4]  [30/70]  eta: 0:01:44  lr: 0.000100  loss: 0.1518 (0.1519)  loss_classifier: 0.0630 (0.0614)  loss_box_reg: 0.0553 (0.0556)  loss_objectness: 0.0225 (0.0228)  loss_rpn_box_reg: 0.0101 (0.0121)  time: 2.6038  data: 0.1648  max mem: 7303
# Epoch: [4]  [40/70]  eta: 0:01:18  lr: 0.000100  loss: 0.1508 (0.1512)  loss_classifier: 0.0636 (0.0615)  loss_box_reg: 0.0566 (0.0553)  loss_objectness: 0.0203 (0.0227)  loss_rpn_box_reg: 0.0082 (0.0117)  time: 2.5949  data: 0.1600  max mem: 7303
# Epoch: [4]  [50/70]  eta: 0:00:52  lr: 0.000100  loss: 0.1465 (0.1513)  loss_classifier: 0.0605 (0.0612)  loss_box_reg: 0.0566 (0.0557)  loss_objectness: 0.0191 (0.0222)  loss_rpn_box_reg: 0.0100 (0.0121)  time: 2.6024  data: 0.1671  max mem: 7303
# Epoch: [4]  [60/70]  eta: 0:00:26  lr: 0.000100  loss: 0.1455 (0.1501)  loss_classifier: 0.0586 (0.0609)  loss_box_reg: 0.0532 (0.0546)  loss_objectness: 0.0228 (0.0228)  loss_rpn_box_reg: 0.0102 (0.0118)  time: 2.5979  data: 0.1655  max mem: 7303
# Epoch: [4]  [69/70]  eta: 0:00:02  lr: 0.000100  loss: 0.1465 (0.1501)  loss_classifier: 0.0582 (0.0609)  loss_box_reg: 0.0536 (0.0554)  loss_objectness: 0.0227 (0.0223)  loss_rpn_box_reg: 0.0096 (0.0115)  time: 2.4753  data: 0.1518  max mem: 7303
# Epoch: [4] Total time: 0:02:59 (2.5688 s / it)
# creating index...
# index created!
# Test:  [ 0/18]  eta: 0:00:18  model_time: 0.8371 (0.8371)  evaluator_time: 0.0181 (0.0181)  time: 1.0384  data: 0.1691  max mem: 7303
# Test:  [17/18]  eta: 0:00:00  model_time: 0.5500 (0.5448)  evaluator_time: 0.0100 (0.0083)  time: 0.7029  data: 0.1469  max mem: 7303
# Test: Total time: 0:00:12 (0.7029 s / it)
# Averaged stats: model_time: 0.5500 (0.5448)  evaluator_time: 0.0100 (0.0083)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.021
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.099
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.180
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.167
# Epoch: [5]  [ 0/70]  eta: 0:03:11  lr: 0.000100  loss: 0.1590 (0.1590)  loss_classifier: 0.0703 (0.0703)  loss_box_reg: 0.0620 (0.0620)  loss_objectness: 0.0150 (0.0150)  loss_rpn_box_reg: 0.0117 (0.0117)  time: 2.7294  data: 0.1879  max mem: 7303
# Epoch: [5]  [10/70]  eta: 0:02:36  lr: 0.000100  loss: 0.1471 (0.1443)  loss_classifier: 0.0626 (0.0627)  loss_box_reg: 0.0546 (0.0558)  loss_objectness: 0.0179 (0.0176)  loss_rpn_box_reg: 0.0083 (0.0081)  time: 2.6004  data: 0.1551  max mem: 7303
# Epoch: [5]  [20/70]  eta: 0:02:11  lr: 0.000100  loss: 0.1439 (0.1484)  loss_classifier: 0.0606 (0.0617)  loss_box_reg: 0.0555 (0.0574)  loss_objectness: 0.0191 (0.0185)  loss_rpn_box_reg: 0.0086 (0.0108)  time: 2.6153  data: 0.1558  max mem: 7303
# Epoch: [5]  [30/70]  eta: 0:01:45  lr: 0.000100  loss: 0.1472 (0.1509)  loss_classifier: 0.0606 (0.0626)  loss_box_reg: 0.0561 (0.0575)  loss_objectness: 0.0205 (0.0201)  loss_rpn_box_reg: 0.0089 (0.0107)  time: 2.6512  data: 0.1675  max mem: 7303
# Epoch: [5]  [40/70]  eta: 0:01:19  lr: 0.000100  loss: 0.1493 (0.1520)  loss_classifier: 0.0637 (0.0630)  loss_box_reg: 0.0536 (0.0576)  loss_objectness: 0.0205 (0.0207)  loss_rpn_box_reg: 0.0079 (0.0108)  time: 2.6676  data: 0.1626  max mem: 7303
# Epoch: [5]  [50/70]  eta: 0:00:52  lr: 0.000100  loss: 0.1493 (0.1511)  loss_classifier: 0.0639 (0.0622)  loss_box_reg: 0.0527 (0.0564)  loss_objectness: 0.0202 (0.0211)  loss_rpn_box_reg: 0.0112 (0.0114)  time: 2.6673  data: 0.1539  max mem: 7303
# Epoch: [5]  [60/70]  eta: 0:00:26  lr: 0.000100  loss: 0.1463 (0.1509)  loss_classifier: 0.0611 (0.0618)  loss_box_reg: 0.0527 (0.0562)  loss_objectness: 0.0228 (0.0216)  loss_rpn_box_reg: 0.0112 (0.0113)  time: 2.6622  data: 0.1695  max mem: 7303
# Epoch: [5]  [69/70]  eta: 0:00:02  lr: 0.000100  loss: 0.1452 (0.1498)  loss_classifier: 0.0574 (0.0612)  loss_box_reg: 0.0542 (0.0555)  loss_objectness: 0.0203 (0.0216)  loss_rpn_box_reg: 0.0090 (0.0114)  time: 2.5305  data: 0.1648  max mem: 7303
# Epoch: [5] Total time: 0:03:02 (2.6115 s / it)
# creating index...
# index created!
# Test:  [ 0/18]  eta: 0:00:20  model_time: 0.9522 (0.9522)  evaluator_time: 0.0102 (0.0102)  time: 1.1476  data: 0.1852  max mem: 7303
# Test:  [17/18]  eta: 0:00:00  model_time: 0.5422 (0.5461)  evaluator_time: 0.0100 (0.0079)  time: 0.7134  data: 0.1594  max mem: 7303
# Test: Total time: 0:00:12 (0.7134 s / it)
# Averaged stats: model_time: 0.5422 (0.5461)  evaluator_time: 0.0100 (0.0079)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.030
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.091
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.136
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.187
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.167
# Epoch: [6]  [ 0/70]  eta: 0:03:13  lr: 0.000010  loss: 0.1362 (0.1362)  loss_classifier: 0.0581 (0.0581)  loss_box_reg: 0.0463 (0.0463)  loss_objectness: 0.0262 (0.0262)  loss_rpn_box_reg: 0.0057 (0.0057)  time: 2.7577  data: 0.1869  max mem: 7303
# Epoch: [6]  [10/70]  eta: 0:02:40  lr: 0.000010  loss: 0.1529 (0.1521)  loss_classifier: 0.0628 (0.0610)  loss_box_reg: 0.0551 (0.0570)  loss_objectness: 0.0188 (0.0212)  loss_rpn_box_reg: 0.0109 (0.0128)  time: 2.6808  data: 0.1738  max mem: 7303
# Epoch: [6]  [20/70]  eta: 0:02:12  lr: 0.000010  loss: 0.1529 (0.1507)  loss_classifier: 0.0622 (0.0616)  loss_box_reg: 0.0578 (0.0579)  loss_objectness: 0.0168 (0.0197)  loss_rpn_box_reg: 0.0102 (0.0115)  time: 2.6361  data: 0.1571  max mem: 7303
# Epoch: [6]  [30/70]  eta: 0:01:45  lr: 0.000010  loss: 0.1492 (0.1505)  loss_classifier: 0.0608 (0.0620)  loss_box_reg: 0.0578 (0.0574)  loss_objectness: 0.0174 (0.0206)  loss_rpn_box_reg: 0.0093 (0.0105)  time: 2.5975  data: 0.1517  max mem: 7303
# Epoch: [6]  [40/70]  eta: 0:01:18  lr: 0.000010  loss: 0.1486 (0.1496)  loss_classifier: 0.0605 (0.0617)  loss_box_reg: 0.0586 (0.0566)  loss_objectness: 0.0199 (0.0211)  loss_rpn_box_reg: 0.0075 (0.0101)  time: 2.5944  data: 0.1627  max mem: 7303
# Epoch: [6]  [50/70]  eta: 0:00:52  lr: 0.000010  loss: 0.1457 (0.1488)  loss_classifier: 0.0586 (0.0609)  loss_box_reg: 0.0500 (0.0548)  loss_objectness: 0.0222 (0.0223)  loss_rpn_box_reg: 0.0080 (0.0108)  time: 2.5948  data: 0.1620  max mem: 7303
# Epoch: [6]  [60/70]  eta: 0:00:26  lr: 0.000010  loss: 0.1493 (0.1493)  loss_classifier: 0.0597 (0.0613)  loss_box_reg: 0.0519 (0.0556)  loss_objectness: 0.0221 (0.0216)  loss_rpn_box_reg: 0.0093 (0.0109)  time: 2.5977  data: 0.1577  max mem: 7303
# Epoch: [6]  [69/70]  eta: 0:00:02  lr: 0.000010  loss: 0.1495 (0.1497)  loss_classifier: 0.0603 (0.0610)  loss_box_reg: 0.0561 (0.0555)  loss_objectness: 0.0180 (0.0218)  loss_rpn_box_reg: 0.0098 (0.0114)  time: 2.4780  data: 0.1565  max mem: 7303
# Epoch: [6] Total time: 0:03:00 (2.5827 s / it)
# creating index...
# index created!
# Test:  [ 0/18]  eta: 0:00:20  model_time: 0.9478 (0.9478)  evaluator_time: 0.0157 (0.0157)  time: 1.1318  data: 0.1592  max mem: 7303
# Test:  [17/18]  eta: 0:00:00  model_time: 0.5466 (0.5479)  evaluator_time: 0.0100 (0.0092)  time: 0.7141  data: 0.1552  max mem: 7303
# Test: Total time: 0:00:12 (0.7141 s / it)
# Averaged stats: model_time: 0.5466 (0.5479)  evaluator_time: 0.0100 (0.0092)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.092
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.139
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.091
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.167
# Epoch: [7]  [ 0/70]  eta: 0:03:10  lr: 0.000010  loss: 0.1588 (0.1588)  loss_classifier: 0.0693 (0.0693)  loss_box_reg: 0.0513 (0.0513)  loss_objectness: 0.0319 (0.0319)  loss_rpn_box_reg: 0.0063 (0.0063)  time: 2.7253  data: 0.1741  max mem: 7303
# Epoch: [7]  [10/70]  eta: 0:02:35  lr: 0.000010  loss: 0.1464 (0.1451)  loss_classifier: 0.0548 (0.0587)  loss_box_reg: 0.0500 (0.0524)  loss_objectness: 0.0211 (0.0225)  loss_rpn_box_reg: 0.0100 (0.0115)  time: 2.5968  data: 0.1624  max mem: 7303
# Epoch: [7]  [20/70]  eta: 0:02:10  lr: 0.000010  loss: 0.1454 (0.1466)  loss_classifier: 0.0579 (0.0591)  loss_box_reg: 0.0537 (0.0557)  loss_objectness: 0.0206 (0.0213)  loss_rpn_box_reg: 0.0091 (0.0105)  time: 2.5969  data: 0.1541  max mem: 7303
# Epoch: [7]  [30/70]  eta: 0:01:43  lr: 0.000010  loss: 0.1494 (0.1500)  loss_classifier: 0.0608 (0.0610)  loss_box_reg: 0.0582 (0.0570)  loss_objectness: 0.0198 (0.0209)  loss_rpn_box_reg: 0.0082 (0.0112)  time: 2.5915  data: 0.1513  max mem: 7303
# Epoch: [7]  [40/70]  eta: 0:01:17  lr: 0.000010  loss: 0.1474 (0.1479)  loss_classifier: 0.0611 (0.0608)  loss_box_reg: 0.0513 (0.0549)  loss_objectness: 0.0198 (0.0211)  loss_rpn_box_reg: 0.0083 (0.0111)  time: 2.5743  data: 0.1548  max mem: 7303
# Epoch: [7]  [50/70]  eta: 0:00:51  lr: 0.000010  loss: 0.1456 (0.1487)  loss_classifier: 0.0596 (0.0609)  loss_box_reg: 0.0513 (0.0556)  loss_objectness: 0.0208 (0.0213)  loss_rpn_box_reg: 0.0083 (0.0109)  time: 2.5863  data: 0.1571  max mem: 7303
# Epoch: [7]  [60/70]  eta: 0:00:25  lr: 0.000010  loss: 0.1456 (0.1486)  loss_classifier: 0.0582 (0.0607)  loss_box_reg: 0.0542 (0.0555)  loss_objectness: 0.0208 (0.0213)  loss_rpn_box_reg: 0.0100 (0.0111)  time: 2.5902  data: 0.1577  max mem: 7303
# Epoch: [7]  [69/70]  eta: 0:00:02  lr: 0.000010  loss: 0.1452 (0.1494)  loss_classifier: 0.0595 (0.0610)  loss_box_reg: 0.0550 (0.0555)  loss_objectness: 0.0188 (0.0216)  loss_rpn_box_reg: 0.0120 (0.0114)  time: 2.4768  data: 0.1527  max mem: 7303
# Epoch: [7] Total time: 0:02:58 (2.5563 s / it)
# creating index...
# index created!
# Test:  [ 0/18]  eta: 0:00:20  model_time: 0.9795 (0.9795)  evaluator_time: 0.0130 (0.0130)  time: 1.1608  data: 0.1683  max mem: 7303
# Test:  [17/18]  eta: 0:00:00  model_time: 0.5604 (0.5626)  evaluator_time: 0.0100 (0.0086)  time: 0.7284  data: 0.1568  max mem: 7303
# Test: Total time: 0:00:13 (0.7290 s / it)
# Averaged stats: model_time: 0.5604 (0.5626)  evaluator_time: 0.0100 (0.0086)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.095
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.140
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.193
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.167
# Epoch: [8]  [ 0/70]  eta: 0:03:14  lr: 0.000010  loss: 0.1740 (0.1740)  loss_classifier: 0.0703 (0.0703)  loss_box_reg: 0.0646 (0.0646)  loss_objectness: 0.0286 (0.0286)  loss_rpn_box_reg: 0.0106 (0.0106)  time: 2.7817  data: 0.1831  max mem: 7303
# Epoch: [8]  [10/70]  eta: 0:02:36  lr: 0.000010  loss: 0.1435 (0.1468)  loss_classifier: 0.0606 (0.0601)  loss_box_reg: 0.0547 (0.0558)  loss_objectness: 0.0194 (0.0198)  loss_rpn_box_reg: 0.0080 (0.0110)  time: 2.6108  data: 0.1579  max mem: 7303
# Epoch: [8]  [20/70]  eta: 0:02:09  lr: 0.000010  loss: 0.1471 (0.1506)  loss_classifier: 0.0591 (0.0595)  loss_box_reg: 0.0540 (0.0553)  loss_objectness: 0.0209 (0.0223)  loss_rpn_box_reg: 0.0090 (0.0135)  time: 2.5853  data: 0.1546  max mem: 7303
# Epoch: [8]  [30/70]  eta: 0:01:43  lr: 0.000010  loss: 0.1471 (0.1476)  loss_classifier: 0.0591 (0.0595)  loss_box_reg: 0.0542 (0.0547)  loss_objectness: 0.0221 (0.0213)  loss_rpn_box_reg: 0.0095 (0.0121)  time: 2.5809  data: 0.1556  max mem: 7303
# Epoch: [8]  [40/70]  eta: 0:01:17  lr: 0.000010  loss: 0.1501 (0.1501)  loss_classifier: 0.0635 (0.0613)  loss_box_reg: 0.0591 (0.0561)  loss_objectness: 0.0215 (0.0213)  loss_rpn_box_reg: 0.0094 (0.0114)  time: 2.5828  data: 0.1580  max mem: 7303
# Epoch: [8]  [50/70]  eta: 0:00:51  lr: 0.000010  loss: 0.1485 (0.1479)  loss_classifier: 0.0592 (0.0605)  loss_box_reg: 0.0547 (0.0550)  loss_objectness: 0.0209 (0.0211)  loss_rpn_box_reg: 0.0087 (0.0113)  time: 2.5871  data: 0.1544  max mem: 7303
# Epoch: [8]  [60/70]  eta: 0:00:25  lr: 0.000010  loss: 0.1427 (0.1488)  loss_classifier: 0.0583 (0.0609)  loss_box_reg: 0.0542 (0.0555)  loss_objectness: 0.0193 (0.0213)  loss_rpn_box_reg: 0.0096 (0.0110)  time: 2.5910  data: 0.1549  max mem: 7303
# Epoch: [8]  [69/70]  eta: 0:00:02  lr: 0.000010  loss: 0.1569 (0.1498)  loss_classifier: 0.0628 (0.0612)  loss_box_reg: 0.0548 (0.0557)  loss_objectness: 0.0208 (0.0216)  loss_rpn_box_reg: 0.0101 (0.0114)  time: 2.4640  data: 0.1462  max mem: 7303
# Epoch: [8] Total time: 0:02:58 (2.5529 s / it)
# creating index...
# index created!
# Test:  [ 0/18]  eta: 0:00:17  model_time: 0.8172 (0.8172)  evaluator_time: 0.0000 (0.0000)  time: 0.9750  data: 0.1578  max mem: 7303
# Test:  [17/18]  eta: 0:00:00  model_time: 0.5545 (0.5484)  evaluator_time: 0.0090 (0.0087)  time: 0.7143  data: 0.1555  max mem: 7303
# Test: Total time: 0:00:12 (0.7143 s / it)
# Averaged stats: model_time: 0.5545 (0.5484)  evaluator_time: 0.0090 (0.0087)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.098
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.167
# Epoch: [9]  [ 0/70]  eta: 0:03:13  lr: 0.000001  loss: 0.1409 (0.1409)  loss_classifier: 0.0557 (0.0557)  loss_box_reg: 0.0541 (0.0541)  loss_objectness: 0.0245 (0.0245)  loss_rpn_box_reg: 0.0066 (0.0066)  time: 2.7605  data: 0.2069  max mem: 7303
# Epoch: [9]  [10/70]  eta: 0:02:35  lr: 0.000001  loss: 0.1526 (0.1504)  loss_classifier: 0.0602 (0.0619)  loss_box_reg: 0.0545 (0.0562)  loss_objectness: 0.0228 (0.0223)  loss_rpn_box_reg: 0.0093 (0.0100)  time: 2.5842  data: 0.1687  max mem: 7303
# Epoch: [9]  [20/70]  eta: 0:02:10  lr: 0.000001  loss: 0.1479 (0.1501)  loss_classifier: 0.0620 (0.0621)  loss_box_reg: 0.0545 (0.0556)  loss_objectness: 0.0197 (0.0212)  loss_rpn_box_reg: 0.0093 (0.0111)  time: 2.6004  data: 0.1628  max mem: 7303
# Epoch: [9]  [30/70]  eta: 0:01:44  lr: 0.000001  loss: 0.1483 (0.1536)  loss_classifier: 0.0604 (0.0623)  loss_box_reg: 0.0556 (0.0572)  loss_objectness: 0.0197 (0.0219)  loss_rpn_box_reg: 0.0106 (0.0121)  time: 2.6404  data: 0.1632  max mem: 7303
# Epoch: [9]  [40/70]  eta: 0:01:18  lr: 0.000001  loss: 0.1468 (0.1512)  loss_classifier: 0.0592 (0.0616)  loss_box_reg: 0.0556 (0.0569)  loss_objectness: 0.0185 (0.0210)  loss_rpn_box_reg: 0.0105 (0.0117)  time: 2.6438  data: 0.1577  max mem: 7303
# Epoch: [9]  [50/70]  eta: 0:00:52  lr: 0.000001  loss: 0.1421 (0.1498)  loss_classifier: 0.0584 (0.0615)  loss_box_reg: 0.0559 (0.0564)  loss_objectness: 0.0183 (0.0210)  loss_rpn_box_reg: 0.0091 (0.0109)  time: 2.6490  data: 0.1568  max mem: 7303
# Epoch: [9]  [60/70]  eta: 0:00:26  lr: 0.000001  loss: 0.1421 (0.1489)  loss_classifier: 0.0573 (0.0610)  loss_box_reg: 0.0553 (0.0558)  loss_objectness: 0.0207 (0.0209)  loss_rpn_box_reg: 0.0084 (0.0112)  time: 2.6532  data: 0.1613  max mem: 7303
# Epoch: [9]  [69/70]  eta: 0:00:02  lr: 0.000001  loss: 0.1460 (0.1491)  loss_classifier: 0.0584 (0.0609)  loss_box_reg: 0.0529 (0.0555)  loss_objectness: 0.0222 (0.0212)  loss_rpn_box_reg: 0.0097 (0.0116)  time: 2.4914  data: 0.1564  max mem: 7303
# Epoch: [9] Total time: 0:03:01 (2.5979 s / it)
# creating index...
# index created!
# Test:  [ 0/18]  eta: 0:00:22  model_time: 0.9750 (0.9750)  evaluator_time: 0.1092 (0.1092)  time: 1.2540  data: 0.1542  max mem: 7303
# Test:  [17/18]  eta: 0:00:00  model_time: 0.5518 (0.5548)  evaluator_time: 0.0100 (0.0145)  time: 0.7293  data: 0.1591  max mem: 7303
# Test: Total time: 0:00:13 (0.7293 s / it)
# Averaged stats: model_time: 0.5518 (0.5548)  evaluator_time: 0.0100 (0.0145)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.098
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.167

# %% [markdown]
# # 5. Decode predictions

# %%
# the function takes the original prediction and the iou threshold.

def apply_nms(orig_prediction, iou_thresh=0.3):
    
    # torchvision returns the indices of the bboxes to keep
    keep = torchvision.ops.nms(orig_prediction['boxes'], orig_prediction['scores'], iou_thresh)
    
    final_prediction = orig_prediction
    final_prediction['boxes'] = final_prediction['boxes'][keep]
    final_prediction['scores'] = final_prediction['scores'][keep]
    final_prediction['labels'] = final_prediction['labels'][keep]
    
    return final_prediction

# function to convert a torchtensor back to numpy array
def torch_to_np(img):
    return img.detach().numpy()

# %% [markdown]
# # 6. Testing the model

# %%
# pick one image from the test set
img, target = dataset_test[5]
img=torch.unsqueeze(img,0)
# put the model in evaluation mode
model.eval()
with torch.no_grad():
    prediction = model([img.to(device)])[0]
    
print('predicted #boxes: ', len(prediction['labels']))
print('real #boxes: ', len(target['labels']))
# Out:
# predicted #boxes:  53
# real #boxes:  1

# %%
print('EXPECTED OUTPUT')
plot_img_bbox(torch_to_np(img[0,:,:]), target)
# Out:
# EXPECTED OUTPUT

# %%
print('MODEL OUTPUT')
prediction={key: value.cpu() for key, value in prediction.items()}
plot_img_bbox(torch_to_np(img[0,:,:]), prediction)
# Out:
# MODEL OUTPUT

# %%
nms_prediction = apply_nms(prediction, iou_thresh=0.2)
print('NMS APPLIED MODEL OUTPUT')
plot_img_bbox(torch_to_np(img[0,:,:]), nms_prediction)
# Out:
# NMS APPLIED MODEL OUTPUT

# %%
test_dataset = dataset_test
# pick one image from the test set
img, target = test_dataset[54] #7,9,16,17,20 incredible
img=torch.unsqueeze(img,0)
# put the model in evaluation mode
model.eval()
with torch.no_grad():
    prediction = model([img.to(device)])[0]
prediction={key: value.cpu() for key, value in prediction.items()}
print('EXPECTED OUTPUT\n')
plot_img_bbox(torch_to_np(img[0,:,:]), target)
print('MODEL OUTPUT\n')
nms_prediction = apply_nms(prediction, iou_thresh=0.01)

plot_img_bbox(torch_to_np(img[0,:,:]), nms_prediction)
# Out:
# EXPECTED OUTPUT
# MODEL OUTPUT

# %%
#torch.save(model, 'First_region_model.pth')
