{"train_lr": 0.00020000000000011442, "train_class_error": 0.0, "train_grad_norm": 86.26652976651299, "train_loss": 6.4637189680222695, "train_loss_ce": 0.7716877624535491, "train_loss_bbox": 0.6313831545806258, "train_loss_giou": 0.7139627951654633, "train_loss_ce_0": 0.8632114541172534, "train_loss_bbox_0": 0.6247010541987335, "train_loss_giou_0": 0.7163772557887617, "train_loss_ce_1": 0.8287532633964914, "train_loss_bbox_1": 0.6126052795133178, "train_loss_giou_1": 0.7010369575045616, "train_loss_ce_unscaled": 0.38584388122677454, "train_class_error_unscaled": 0.0, "train_loss_bbox_unscaled": 0.12627663044990697, "train_loss_giou_unscaled": 0.3569813975827317, "train_cardinality_error_unscaled": 29.000034766010874, "train_loss_ce_0_unscaled": 0.4316057270586267, "train_loss_bbox_0_unscaled": 0.12494021038065167, "train_loss_giou_0_unscaled": 0.35818862789438083, "train_cardinality_error_0_unscaled": 79.00000290014601, "train_loss_ce_1_unscaled": 0.4143766316982457, "train_loss_bbox_1_unscaled": 0.12252105541069834, "train_loss_giou_1_unscaled": 0.3505184787522808, "train_cardinality_error_1_unscaled": 49.0000405605339, "epoch": 3, "n_parameters": 106274744},

]

# %%
train_loss=[]
train_loss_ce=[]
train_loss_bbox=[]
train_loss_giou=[]
learning_rate=[]
epochs_vect=[]
for i, epochs in enumerate(data) :
    train_loss.append(epochs["train_loss"])
    train_loss_ce.append(epochs["train_loss_ce"])
    train_loss_bbox.append(epochs["train_loss_bbox"])
    train_loss_giou.append(epochs["train_loss_giou"])
    epochs_vect.append(i)
    learning_rate.append(epochs["train_lr"])

# %%
plt.title("Training Losses")

plt.plot(epochs_vect,train_loss_ce)
plt.plot(epochs_vect,train_loss_bbox)
plt.plot(epochs_vect, train_loss_giou)
plt.legend(["train_loss_ce", "train_loss_bbox", "train_loss_giou"])
plt.xlabel("epochs")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %% [markdown]
# Overall training loss

# %%
plt.title("Overall Training loss")
plt.plot(epochs_vect,train_loss)
plt.xlabel("Epochs")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.title("Learning rate scheduler")

plt.plot(epochs_vect,learning_rate)
plt.xlabel("epochs")
plt.ylabel("Learning Rate")
plt.yscale("log")
plt.ylim([1e-6, 1e-3])
# Out:
# (1e-06, 0.001)

# %% [markdown]
# # From Evaluation function on validation dataset:

# %% [markdown]
# MaxDets stands for the maximum number of detection per image
# Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = AP_50_95
# Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = AP_50
# Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = AP_75
# Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = AP_50_95_small
# Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = AP_50_95_medium
# Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = AP_50_95_large
# Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = AR_1
# Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = AR_10
# Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = AR_100
# Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = AR_100_small
# Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = AR_100_medium
# Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = AR_100_large

# %%
"""
"0":{
    "AP_50_95":0.038,
    "AP_50":0.117,
    "AP_75":0.012,
    "AP_50_95_small":-1.000,
    "AP_50_95_medium":0.032,
    "AP_50_95_large":0.039,
    "AR_1":0.115,
    "AR_10":0.261,
    "AR_100":0.335,
    "AR_100_small":-1.000,
    "AR_100_medium":0.224,
    "AR_100_large":0.399
},"""
data={ 
"0":{ #Checkpoint 0
    "AP_50_95":0.035,
    "AP_50":0.110,
    "AP_75":0.018,
    "AP_50_95_small":-1.000,
    "AP_50_95_medium":0.021,
    "AP_50_95_large":0.043,
    "AR_1":0.096,
    "AR_10":0.213,
    "AR_100":0.271,
    "AR_100_small":-1.000,
    "AR_100_medium":0.172,
    "AR_100_large":0.328
},
"1":{ #Checkpoint 1
    "AP_50_95":0.031,
    "AP_50":0.119,
    "AP_75":0.008,
    "AP_50_95_small":-1.000,
    "AP_50_95_medium":0.019,
    "AP_50_95_large":0.039,
    "AR_1":0.095,
    "AR_10":0.263,
    "AR_100":0.325,
    "AR_100_small":-1.000,
    "AR_100_medium":0.206,
    "AR_100_large":0.393
},

"2":{ 
    "AP_50_95":0.041,
    "AP_50":0.140,
    "AP_75":0.009,
    "AP_50_95_small":-1.000,
    "AP_50_95_medium":0.024,
    "AP_50_95_large":0.051,
    "AR_1":0.106,
    "AR_10":0.261,
    "AR_100":0.338,
    "AR_100_small":-1.000,
    "AR_100_medium":0.217,
    "AR_100_large":0.408
},
"3":{ 
    "AP_50_95":0.038,
    "AP_50":0.117,
    "AP_75":0.012,
    "AP_50_95_small":-1.000,
    "AP_50_95_medium":0.032,
    "AP_50_95_large":0.039,
    "AR_1":0.115,
    "AR_10":0.261,
    "AR_100":0.335,
    "AR_100_small":-1.000,
    "AR_100_medium":0.224,
    "AR_100_large":0.399
},

"4":{ 
    "AP_50_95":0.041,
    "AP_50":0.123,
    "AP_75":0.013,
    "AP_50_95_small":-1.000,
    "AP_50_95_medium":0.045,
    "AP_50_95_large":0.040,
    "AR_1":0.113,
    "AR_10":0.248,
    "AR_100":0.330,
    "AR_100_small":-1.000,
    "AR_100_medium":0.278,
    "AR_100_large":0.360
},

}

# %%
# Extract epochs
epochs = list(data.keys())

# Extract AP and AR metrics
overall_ap_metrics = ['AP_50_95', 'AP_50', 'AP_75']
size_ap_metrics = ['AP_50_95_medium', 'AP_50_95_large']
overall_ar_metrics = ['AR_1', 'AR_10', 'AR_100']
size_ar_metrics = ['AR_100_medium', 'AR_100_large']

def plot_metrics(metrics, title, ylabel, vertical_line_epochs=None, annotation_texts=None):
    plt.figure(figsize=(14, 7))
    
    # Initialize a variable to store the global maximum value for annotation positioning
    global_max_value = float('-inf')
    
    for metric in metrics:
        values = [data[epoch][metric] for epoch in epochs]
        plt.plot(epochs, values, marker='o', label=metric)
        # Update the global maximum value if the current metric's max is higher
        max_value = max(values)
        if max_value > global_max_value:
            global_max_value = max_value
    
    # Add vertical lines and annotations
    if vertical_line_epochs is not None and annotation_texts is not None:
        for i in range(len(vertical_line_epochs)):
            plt.axvline(x=vertical_line_epochs[i], color='red', linestyle='--', linewidth=2)
            # Position the text just above the grid of the plot
            plt.text(vertical_line_epochs[i], global_max_value + (global_max_value * 0.05),  # Slightly above the maximum value
                     annotation_texts[i], color='red', ha='center')
    
    plt.title(title, pad=20)  # Adjust the pad value to move the title higher
    plt.xlabel('Epochs')
    plt.ylabel(ylabel)
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage with multiple vertical lines and annotation texts
plot_metrics(overall_ap_metrics, 'Average Precision (AP) Metrics - Overall', 'AP', vertical_line_epochs=[12, 14], annotation_texts=["↓ lr", "↓ lr"])

# Plot Average Precision (Small, Medium, Large) with a single vertical line and annotation
plot_metrics(size_ap_metrics, 'Average Precision (AP) Metrics - Medium, Large', 'AP', vertical_line_epochs=[12, 14], annotation_texts=["↓ lr", "↓ lr"])

# Plot Average Recall (Overall) with a single vertical line and annotation
plot_metrics(overall_ar_metrics, 'Average Recall (AR) Metrics - Overall', 'AR', vertical_line_epochs=[12, 14], annotation_texts=["↓ lr", "↓ lr"])

# Plot Average Recall (Small, Medium, Large) with a single vertical line and annotation
plot_metrics(size_ar_metrics, 'Average Recall (AR) Metrics - Medium, Large', 'AR', vertical_line_epochs=[12, 14], annotation_texts=["↓ lr", "↓ lr"])
