    epochs_vect.append(i)
    learning_rate.append(epochs["train_lr"])

# %%
plt.figure(figsize=(5,5))
plt.title("Training Losses")
plt.xticks(epochs_vect)
plt.plot(epochs_vect,train_loss_ce)
plt.plot(epochs_vect,train_loss_bbox)
plt.plot(epochs_vect, train_loss_giou)
plt.legend(["loss ce", "loss bbox", "loss giou"])
plt.xlabel("epochs")
plt.ylabel("Value")
plt.show()

# %%
plt.title("Overall Training loss")
plt.plot(epochs_vect,train_loss)
plt.xticks(epochs_vect)
plt.xlabel("Epochs")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.title("Learning rate scheduler")
plt.xticks(epochs_vect)
plt.plot(epochs_vect,learning_rate)
plt.xlabel("epochs")
plt.ylabel("Learning Rate")
plt.yscale("log")
plt.ylim([1e-7, 1e-3])
# Out:
# (1e-07, 0.001)

# %% [markdown]
# # Evalutaion model DATA

# %%
import re
import json

def parse_text_to_dict(text):
    # Split the text into blocks, each block corresponds to one run
    blocks = text.strip().split('\n\n')
    
    result_dict = {}
    
    for block in blocks:
        lines = block.strip().split('\n')
        run_id = lines[0].strip(':')
        
        # Initialize a dictionary for this run
        run_dict = {}
        
        for line in lines[1:]:
            # Extract the key and value using regular expressions
            match = re.match(r'.*\[\s*IoU=\s*(0\.50|0\.75|0\.50:0\.95)\s*\|\s*area=\s*(small|medium|large|all)\s*\|\s*maxDets=(\d+)\s*\]\s*=\s*([\d\.\-]+)', line)
            if match:
                iou, area, max_dets, value = match.groups()
                value = float(value)
                
                # Convert the key to the desired format
                if "AP" in line:
                    key = f"AP_{iou.replace(':', '_')}_{area}_{max_dets}"
                elif "AR" in line:
                    key = f"AR_{iou.replace(':', '_')}_{area}_{max_dets}"
                run_dict[key] = value
            else:
                # Handle lines where the regular expression does not match
                parts = re.split(r'\s*=\s*', line.strip())
                if len(parts) == 5:
                    key ="AR_0.50_0.95_all_"+parts[3][0:2]
                    value = float(parts[4].strip())
                    run_dict[key] = value
                
        result_dict[run_id] = run_dict
    
    return result_dict


with open('./exps/multi_model_jet/FINAL_PROJECT_train4_2/FINAL_PROJECT_train4_2/results.txt', 'r') as file:
    text = file.read()

result = parse_text_to_dict(text)
with open('./exps/multi_model_jet/FINAL_PROJECT_train4_2/FINAL_PROJECT_train4_2/results.json', 'w') as json_file:
    json.dump(result, json_file, indent=4)

# %%
import json
import os

# Directory where JSON files are located
json_directory = "./exps/multi_model_jet/FINAL_PROJECT_train4_2/FINAL_PROJECT_train4_2"

# Initialize variables to store data from each JSON file
data_dict1 = {}

# Iterate over each JSON file in the directory
for filename in os.listdir(json_directory):
    if filename.endswith(".json"):
        filepath = os.path.join(json_directory, filename)
        # Read the JSON file
        with open(filepath, 'r') as file:
            data = json.load(file)
            # Store data into respective variables based on the file name
            if filename == "results.json":
                data_dict1 = data

# %%
import matplotlib.pyplot as plt
import numpy as np  # Import numpy for color generation

# Define a color cycle for the plot
color_cycle = ["blue","green","blue","yellow","black"]  # Change 5 to the number of data dictionaries you have

# Extract epochs
epochs = list(data_dict1.keys())

# Extract AP and AR metrics
overall_ap_metrics = ['AP_0.50_0.95_all_100', 'AP_0.50_all_100', 'AP_0.75_all_100']
size_ap_metrics = ['AP_0.50_0.95_medium_100', 'AP_0.50_0.95_large_100']
overall_ar_metrics = ['AR_0.50_0.95_all_1 ', 'AR_0.50_0.95_all_10', 'AR_0.50_0.95_all_100']
size_ar_metrics = ['AR_0.50_0.95_medium_100', 'AR_0.50_0.95_large_100']

def plot_metrics(data_dicts, title, ylabel, metrics_to_plot, vertical_line_epochs=None, annotation_texts=None, ):
    plt.figure(figsize=(14, 7))
    global_max_value = float('-inf')
    
    for i, data_dict in enumerate(data_dicts):
        color = color_cycle[i % len(color_cycle)]  # Cycle through the color palette for each data dictionary
        epochs = list(data_dict.keys())
        for a,metric in enumerate(metrics_to_plot):
            if color=="red":
                colors_dict=["red", "firebrick", "indianred"]
            elif color=="green":
                colors_dict=["green","olivedrab", "mediumseagreen"]
            elif color=="blue":
                colors_dict=["blue","deepskyblue", "slateblue"]
            elif color=="yellow":
                colors_dict=["yellow","gold", "goldenrod"]
            elif color=="black":
                colors_dict=["black","dimgray", "silver"]

            values = [data_dict[epoch][metric] for epoch in epochs]
            plt.plot(epochs, values, marker='o', label=metric, color=colors_dict[a])
            max_value = max(values)
            if max_value > global_max_value:
                global_max_value = max_value
    
    # Add vertical lines and annotations
    if vertical_line_epochs is not None and annotation_texts is not None:
        for i in range(len(vertical_line_epochs)):
            plt.axvline(x=vertical_line_epochs[i], color='red', linestyle='--', linewidth=2)
            # Position the text just above the grid of the plot
            plt.text(vertical_line_epochs[i], global_max_value + (global_max_value * 0.05),  # Slightly above the maximum value
                     annotation_texts[i], color='red', ha='center')    

    plt.title(title, pad=20)  # Adjust the pad value to move the title higher
    plt.xlabel('Epochs')
    plt.ylabel(ylabel)
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage with multiple data dictionaries
plot_metrics([data_dict1], 'Average Precision (AP) Metrics - Overall', 'AP', overall_ap_metrics, vertical_line_epochs=[8, 10], annotation_texts=["↓ lr", "↓ lr"])

# Plot Average Precision (Small, Medium, Large) with a single vertical line and annotation
plot_metrics([data_dict1], 'Average Precision (AP) Metrics - Medium, Large', 'AP', size_ap_metrics,vertical_line_epochs=[8, 10], annotation_texts=["↓ lr", "↓ lr"])

# Plot Average Recall (Overall) with a single vertical line and annotation
plot_metrics([data_dict1], 'Average Recall (AR) Metrics - Overall', 'AR', overall_ar_metrics,vertical_line_epochs=[8, 10], annotation_texts=["↓ lr", "↓ lr"])

# Plot Average Recall (Small, Medium, Large) with a single vertical line and annotation
plot_metrics([data_dict1], 'Average Recall (AR) Metrics - Medium, Large', 'AR', size_ar_metrics, vertical_line_epochs=[8, 10], annotation_texts=["↓ lr", "↓ lr"])

# %% [markdown]
# # AUC (Area under curve) plot

# %%
precision=[data_dict1[epoch]['AP_0.50_all_100'] for epoch in epochs]
recall=[data_dict1[epoch]['AR_0.50_0.95_all_1 '] for epoch in epochs]
# Plot Precision-Recall points
plt.figure(figsize=(10, 6))
plt.scatter(recall, precision, color='b', label='Precision-Recall Points')

# Adding title and labels
plt.title('Precision-Recall Points', fontsize=16)
plt.xlabel('Recall', fontsize=14)
plt.ylabel('Precision', fontsize=14)

# Adding grid lines
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Adding a legend
plt.legend(loc='best')

# Adding annotations for each data point
for i in range(len(epochs)):
    plt.annotate(f'Epoch {epochs[i]}', (recall[i], precision[i]), textcoords="offset points", xytext=(0, 10), ha='center')

# Show the plot
plt.show()
